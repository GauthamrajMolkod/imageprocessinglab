# %%
# import OS module
import os
 
# Get the list of all files and directories
path = "C:/Users/CCL/Downloads"
dir_list = os.listdir(path)
 
print("Files and directories in '", path, "' :")
 
# prints all files

for dir_list in os.listdir(path):
    print(dir_list)
# Out:
# Files and directories in ' C:/Users/CCL/Downloads ' :
# !qhlogs.doc
# 1.jpg
# 1183540384.pdf
# 2.3.0
# about.html
# account
# AI_ML_FINAL_RECORD (1).pdf
# AI_ML_FINAL_RECORD.pdf
# Anaconda3-2022.05-Windows-x86_64.exe
# Anaconda3-2022.10-Windows-x86_64.exe
# android-studio-2021.3.1.17-windows.exe
# android_kotlin_Job-Allocation_app.zip
# apple-touch-icon-114x114-precomposed.png
# apple-touch-icon-120x120-precomposed.png
# apple-touch-icon-144x144-precomposed.png
# apple-touch-icon-152x152-precomposed.png
# apple-touch-icon-180x180-precomposed.png
# apple-touch-icon-72x72-precomposed.png
# apple-touch-icon-76x76-precomposed.png
# apple-touch-icon-precomposed.png
# archive
# archive (1) (1).zip
# archive (1).zip
# archive (2) (1).zip
# archive (2) (2).zip
# archive (2) (3).zip
# archive (2).zip
# archive (3).zip
# archive (4).zip
# archive.zip
# Augmented Images
# bert-base.state_dict
# bert_nli-master
# bert_nli-master.zip
# BERT_XNLI_kn.ipynb
# bin
# boxfil.png
# brilliant.org_krrao.rao_gmail.com_qaoglk3cbd_backup.zip
# bubblingFish.jpg
# calvinHobbes.jpeg
# canny.jpg
# CannyFish.jpg
# careers-categories
# careers.html
# cars.xml
# circle-ring.png
# Contours (1).jpg
# Contours.jpg
# contrib
# cut_messi.jpg
# Cyber Lab Management(admin).docx
# Cyber Lab Management(admin).pdf
# data center 2.docx
# Data center certificate.docx
# DATASTRUCTURE LABPROG.pdf
# Data_Analysis.ipynb - Colaboratory.html
# Data_Analysis.ipynb - Colaboratory_files
# desktop.ini
# Dev-Cpp 5.11 TDM-GCC 4.9.2 Setup.exe
# devcpp-4.9.9.2_setup (1).exe
# devcpp-4.9.9.2_setup.exe
# DFT.png
# dilate.jpg
# dummy_data
# EPS
# equal-hist.png
# Equalized Image.png
# erode.jpg
# etc
# f.jfif
# favicon.ico
# files_count.xml
# file_example_MP4_1280_10MG.mp4
# file_example_MP4_480_1_5MG.mp4
# file_example_MP4_640_3MG.mp4
# Fine-tuning-BERT-for-NLI-master
# Fine-tuning-BERT-for-NLI-master.zip
# flower.jpg
# Fold1
# Fold1-20230203T091637Z-001.zip
# geetha2
# geethanjali
# Git-2.37.3-64-bit.exe
# git-lfs-windows-v3.2.0.exe
# hist (1).png
# hist.png
# hough.jpg
# idft.jpg
# image
# image.jpg
# images
# INDEX UPDATED(AKSHAY).docx
# INDEX UPDATED(AKSHAY).pdf
# index.html
# IndicXNLI-main
# IndicXNLI-main.zip
# job-portal-android.zip
# khalid (1).pdf
# khalid (2).pdf
# khalid.pdf
# LargestContour.jpg
# Linear Algebra step by step (Singh, Kuldeep) (z-lib.org).pdf
# lowContrast.png
# man
# manifest
# Merge Sort.docx
# messi.jpg
# Monkey Pox-20230203T112732Z-001.zip
# n.jpg
# NearestNeighbour.jpg
# NotificationJava.zip
# orig.png
# Original Images
# original.jpg
# page.jpg
# panda.jpg
# panda1.jpg
# parrot.jfif
# parrot1.jfif
# pexels.jpeg
# phonecall
# phonecall.zip
# pneu3.py
# pneu3_upgrade.ipynb
# polygons.jpg
# principles.html
# putty-64bit-0.78-installer.msi
# Pyaar Hota Kayi Baar Hai(PagalWorld.com.pe).mp3
# qrcode_stackabuse.com.png
# recaptcha
# report_to_create_file.txt
# requirements.txt
# resnetv2-accuracy-100-no-overfitting-tl (1).ipynb
# resnetv2-accuracy-100-no-overfitting-tl.ipynb
# s.png
# saas.txt
# Screenshot from 2020-08-14 23-16-57.png
# Screenshot_20220616_111610.jpg
# script
# SETEPS.TEX
# share
# site_media
# snli_1.0
# snli_1.0.zip
# staff-avatars
# sudoku.jpg
# tf00001031_wac.pptx
# Threshold.jpg
# Translation.jpg
# TRENCH_IMPROPER_FUNCTIONS.tex
# TRENCH_LAGRANGE_MULTIPLIERS.tex
# TRENCH_REAL_ANALYSIS.tex
# TRENCH_REAL_ANALYSIS.zip
# Triangles.jpg
# Turbo.C.3.2
# Turbo.C.3.2.zip
# ui-min (1).png
# uncased_L-4_H-512_A-8.zip
# Untitled.ipynb
# Untitled.png
# Untitled0.ipynb
# Untitled1.ipynb
# User_Data (1).csv
# User_Data (2).csv
# User_Data (3).csv
# User_Data (4).csv
# User_Data (5).csv
# User_Data.csv
# vue-query.svg
# warmed.jpg
# water.png
# water.webp
# welcome.html
# wget (1).exe
# wget-1.11.4-1-bin.zip
# wget.exe
# William Stallings - Effective Cybersecurity_ A Guide to Using Best Practices and Standards (2018, Addison-Wesley Professional) - libgen.li.pdf
# wtrench.sty
# XNLI-1.0.zip
# __MACOSX

# %%
# import the modules
import os
from os import listdir
 
# get the path/directory
folder_dir = "C:/Users/CCL/Downloads"
for images in os.listdir(folder_dir):
 
    # check if the image ends with png
    if (images.endswith(".png")):
        print(images)
# Out:
# apple-touch-icon-114x114-precomposed.png
# apple-touch-icon-120x120-precomposed.png
# apple-touch-icon-144x144-precomposed.png
# apple-touch-icon-152x152-precomposed.png
# apple-touch-icon-180x180-precomposed.png
# apple-touch-icon-72x72-precomposed.png
# apple-touch-icon-76x76-precomposed.png
# apple-touch-icon-precomposed.png
# boxfil.png
# circle-ring.png
# DFT.png
# equal-hist.png
# Equalized Image.png
# hist (1).png
# hist.png
# lowContrast.png
# orig.png
# qrcode_stackabuse.com.png
# s.png
# Screenshot from 2020-08-14 23-16-57.png
# ui-min (1).png
# Untitled.png
# water.png

# %%
# import the modules
import os
from os import listdir
 
# get the path/directory
folder_dir = "C:/Users/CCL/Downloads"
for images in os.listdir(folder_dir):
 
    # check if the image ends with png
    if (images.endswith(".jpg")):
        print(images)
# Out:
# 1.jpg
# bubblingFish.jpg
# canny.jpg
# CannyFish.jpg
# Contours (1).jpg
# Contours.jpg
# cut_messi.jpg
# dilate.jpg
# erode.jpg
# flower.jpg
# hough.jpg
# idft.jpg
# image.jpg
# LargestContour.jpg
# messi.jpg
# n.jpg
# NearestNeighbour.jpg
# original.jpg
# page.jpg
# panda.jpg
# panda1.jpg
# polygons.jpg
# Screenshot_20220616_111610.jpg
# sudoku.jpg
# Threshold.jpg
# Translation.jpg
# Triangles.jpg
# warmed.jpg

# %%
# import the modules
import os
from os import listdir
 
# get the path/directory
folder_dir = "C:/Users/CCL/Downloads"
for images in os.listdir(folder_dir):
 
    # check if the image ends with png
    if (images.endswith(".mp4")):
        print(images)
# Out:
# file_example_MP4_1280_10MG.mp4
# file_example_MP4_480_1_5MG.mp4
# file_example_MP4_640_3MG.mp4
