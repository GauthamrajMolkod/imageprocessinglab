# %%
conda install -c conda-forge opencv
# Out:
# ^C
#
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install opencv-contrib-python
import cv2

print(cv2.__version__)
# Out:
# Requirement already satisfied: opencv-contrib-python in c:\users\ccl\anaconda3\lib\site-packages (4.7.0.72)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\ccl\appdata\roaming\python\python39\site-packages (from opencv-contrib-python) (1.21.4)
# 4.7.0

# %%
# !pip install numpy scipy matplotlib scikit-learn jupyter
# Out:
# Requirement already satisfied: numpy in c:\users\ccl\appdata\roaming\python\python39\site-packages (1.21.4)
# Requirement already satisfied: scipy in c:\users\ccl\appdata\roaming\python\python39\site-packages (1.7.3)
# Requirement already satisfied: matplotlib in c:\users\ccl\appdata\roaming\python\python39\site-packages (3.5.1)
# Requirement already satisfied: scikit-learn in c:\users\ccl\appdata\roaming\python\python39\site-packages (1.0.1)
# Requirement already satisfied: jupyter in c:\users\ccl\anaconda3\lib\site-packages (1.0.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ccl\appdata\roaming\python\python39\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\ccl\appdata\roaming\python\python39\site-packages (from matplotlib) (3.0.6)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\ccl\appdata\roaming\python\python39\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ccl\appdata\roaming\python\python39\site-packages (from matplotlib) (4.28.3)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\ccl\appdata\roaming\python\python39\site-packages (from matplotlib) (8.4.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\ccl\appdata\roaming\python\python39\site-packages (from matplotlib) (21.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\ccl\appdata\roaming\python\python39\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\ccl\appdata\roaming\python\python39\site-packages (from scikit-learn) (3.0.0)
# Requirement already satisfied: joblib>=0.11 in c:\users\ccl\appdata\roaming\python\python39\site-packages (from scikit-learn) (1.1.0)
# Requirement already satisfied: nbconvert in c:\users\ccl\anaconda3\lib\site-packages (from jupyter) (6.4.4)
# Requirement already satisfied: ipywidgets in c:\users\ccl\anaconda3\lib\site-packages (from jupyter) (7.6.5)
# Requirement already satisfied: notebook in c:\users\ccl\anaconda3\lib\site-packages (from jupyter) (6.4.8)
# Requirement already satisfied: qtconsole in c:\users\ccl\anaconda3\lib\site-packages (from jupyter) (5.3.0)
# Requirement already satisfied: jupyter-console in c:\users\ccl\anaconda3\lib\site-packages (from jupyter) (6.4.0)
# Requirement already satisfied: ipykernel in c:\users\ccl\anaconda3\lib\site-packages (from jupyter) (6.9.1)
# Requirement already satisfied: six>=1.5 in c:\users\ccl\appdata\roaming\python\python39\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: nest-asyncio in c:\users\ccl\anaconda3\lib\site-packages (from ipykernel->jupyter) (1.5.5)
# Requirement already satisfied: jupyter-client<8.0 in c:\users\ccl\anaconda3\lib\site-packages (from ipykernel->jupyter) (6.1.12)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in c:\users\ccl\anaconda3\lib\site-packages (from ipykernel->jupyter) (1.5.1)
# Requirement already satisfied: traitlets<6.0,>=5.1.0 in c:\users\ccl\anaconda3\lib\site-packages (from ipykernel->jupyter) (5.1.1)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in c:\users\ccl\anaconda3\lib\site-packages (from ipykernel->jupyter) (0.1.2)
# Requirement already satisfied: tornado<7.0,>=4.2 in c:\users\ccl\anaconda3\lib\site-packages (from ipykernel->jupyter) (6.1)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\ccl\anaconda3\lib\site-packages (from ipykernel->jupyter) (8.2.0)
# Requirement already satisfied: colorama in c:\users\ccl\appdata\roaming\python\python39\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.4.5)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\ccl\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (2.11.2)
# Requirement already satisfied: decorator in c:\users\ccl\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (5.1.1)
# Requirement already satisfied: setuptools>=18.5 in c:\users\ccl\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (61.2.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\ccl\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (3.0.20)
# Requirement already satisfied: jedi>=0.16 in c:\users\ccl\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.18.1)
# Requirement already satisfied: backcall in c:\users\ccl\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.2.0)
# Requirement already satisfied: stack-data in c:\users\ccl\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.2.0)
# Requirement already satisfied: pickleshare in c:\users\ccl\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.7.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\ccl\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter) (0.8.3)
# Requirement already satisfied: jupyter-core>=4.6.0 in c:\users\ccl\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel->jupyter) (4.9.2)
# Requirement already satisfied: pyzmq>=13 in c:\users\ccl\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel->jupyter) (22.3.0)
# Requirement already satisfied: pywin32>=1.0 in c:\users\ccl\anaconda3\lib\site-packages (from jupyter-core>=4.6.0->jupyter-client<8.0->ipykernel->jupyter) (302)
# Requirement already satisfied: wcwidth in c:\users\ccl\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=7.23.1->ipykernel->jupyter) (0.2.5)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\ccl\anaconda3\lib\site-packages (from ipywidgets->jupyter) (0.2.0)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\ccl\anaconda3\lib\site-packages (from ipywidgets->jupyter) (5.3.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\ccl\anaconda3\lib\site-packages (from ipywidgets->jupyter) (3.5.2)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\users\ccl\anaconda3\lib\site-packages (from ipywidgets->jupyter) (1.0.0)
# Requirement already satisfied: fastjsonschema in c:\users\ccl\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets->jupyter) (2.15.1)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\ccl\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets->jupyter) (4.4.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\ccl\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets->jupyter) (0.18.0)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\ccl\appdata\roaming\python\python39\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets->jupyter) (21.2.0)
# Requirement already satisfied: jinja2 in c:\users\ccl\anaconda3\lib\site-packages (from notebook->jupyter) (2.11.3)
# Requirement already satisfied: Send2Trash>=1.8.0 in c:\users\ccl\anaconda3\lib\site-packages (from notebook->jupyter) (1.8.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\ccl\anaconda3\lib\site-packages (from notebook->jupyter) (0.13.1)
# Requirement already satisfied: argon2-cffi in c:\users\ccl\anaconda3\lib\site-packages (from notebook->jupyter) (21.3.0)
# Requirement already satisfied: prometheus-client in c:\users\ccl\anaconda3\lib\site-packages (from notebook->jupyter) (0.13.1)
# Requirement already satisfied: pywinpty>=1.1.0 in c:\users\ccl\anaconda3\lib\site-packages (from terminado>=0.8.3->notebook->jupyter) (2.0.2)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\ccl\anaconda3\lib\site-packages (from argon2-cffi->notebook->jupyter) (21.2.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\ccl\anaconda3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->notebook->jupyter) (1.15.0)
# Requirement already satisfied: pycparser in c:\users\ccl\anaconda3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook->jupyter) (2.21)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\ccl\anaconda3\lib\site-packages (from jinja2->notebook->jupyter) (2.0.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\ccl\anaconda3\lib\site-packages (from nbconvert->jupyter) (4.11.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\ccl\anaconda3\lib\site-packages (from nbconvert->jupyter) (0.1.2)
# Requirement already satisfied: defusedxml in c:\users\ccl\anaconda3\lib\site-packages (from nbconvert->jupyter) (0.7.1)
# Requirement already satisfied: bleach in c:\users\ccl\anaconda3\lib\site-packages (from nbconvert->jupyter) (4.1.0)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\ccl\anaconda3\lib\site-packages (from nbconvert->jupyter) (0.5.13)
# Requirement already satisfied: testpath in c:\users\ccl\anaconda3\lib\site-packages (from nbconvert->jupyter) (0.5.0)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\users\ccl\anaconda3\lib\site-packages (from nbconvert->jupyter) (0.4)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\ccl\anaconda3\lib\site-packages (from nbconvert->jupyter) (0.8.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\ccl\anaconda3\lib\site-packages (from nbconvert->jupyter) (1.5.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\ccl\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert->jupyter) (2.3.1)
# Requirement already satisfied: webencodings in c:\users\ccl\anaconda3\lib\site-packages (from bleach->nbconvert->jupyter) (0.5.1)
# Requirement already satisfied: qtpy>=2.0.1 in c:\users\ccl\anaconda3\lib\site-packages (from qtconsole->jupyter) (2.0.1)
# Requirement already satisfied: asttokens in c:\users\ccl\anaconda3\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\ccl\anaconda3\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter) (0.2.2)
# Requirement already satisfied: executing in c:\users\ccl\anaconda3\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter) (0.8.3)

# %%
import cv2
img=cv2.imread("C:/Users/CCL/Downloads/water.png")

# %%
cv2.imshow('water',img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2

image = cv2.imread("C:/Users/CCL/Downloads/water.png")
B, G, R = cv2.split(image)
# Corresponding channels are separated

cv2.imshow("original", image)
cv2.waitKey(0)

cv2.imshow("blue", B)
cv2.waitKey(0)

cv2.imshow("Green", G)
cv2.waitKey(0)

cv2.imshow("red", R)
cv2.waitKey(0)

cv2.destroyAllWindows()

# %%
import glob
import cv2
path="C:/Users/CCL/Downloads/image/*.jpg"    
images=[cv2.imread(images) for images in glob.glob(path)]

for i in range(len(images)):
    cv2.imshow("images",images[i])
    cv2.waitKey(1)
    cv2.destroyAllWindows

# %%
import matplotlib.pyplot as plt
import matplotlib.image as img
images= img.imread("C:/Users/CCL/Downloads/water.png" )
plt.imshow(images)

# %%
import cv2
from matplotlib import pyplot as plt
  
# create figure
fig = plt.figure(figsize=(10, 7))
  
# setting values to rows and column variables
rows = 2
columns = 4
  
# reading images
Image1 = cv2.imread("C:/Users/CCL/Downloads/image/CannyFish.jpg")
Image2 = cv2.imread("C:/Users/CCL/Downloads/image/panda.jpg")
Image3 = cv2.imread("C:/Users/CCL/Downloads/image/flower.jpg")
Image4 = cv2.imread("C:/Users/CCL/Downloads/image/polygons.jpg")
  
# Adds a subplot at the 1st position
fig.add_subplot(rows, columns, 1)
  
# showing image
plt.imshow(Image1)
plt.axis('on')
plt.title("Image2")
  
# Adds a subplot at the 2nd position
fig.add_subplot(rows, columns, 2)
  
# showing image
plt.imshow(Image2)
plt.axis('on')
plt.title("Image3")
  
# Adds a subplot at the 3rd position
fig.add_subplot(rows, columns, 3)
  
# showing image
plt.imshow(Image3)
plt.axis('on')
plt.title("Image4")
  
# Adds a subplot at the 4th position
fig.add_subplot(rows,columns,4)
  
# showing image
plt.imshow(Image4)
plt.axis('on')
plt.title("Image5")
# Out:
# Text(0.5, 1.0, 'Image5')
